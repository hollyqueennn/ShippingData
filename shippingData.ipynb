# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = pd.read_csv('Train.csv.xls')
data.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
data.shape
# Out:
# (10999, 12)

# %%
data.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
data.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
data.drop('ID', axis = 1, inplace = True)
data.head()
# Out:
#   Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0               D           Flight                    4                2
# 1               F           Flight                    4                5
# 2               A           Flight                    2                2
# 3               B           Flight                    3                3
# 4               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# ...

# %%
# Mengambil kolom numerik
data_numeric = data.select_dtypes(include=['number'])

# Menghitung matriks korelasi
correlation_matrix = data_numeric.corr()

# Membuat heatmap dari matriks korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Kesimpulan
# - Reached on time memiliki korelasi positif dengan discount offered yaitu 40%
# - Reached on time memiliki korelasi negatif dengan weigth in grams yaitu -27%
# - Weigth in grams memiliki korelasi negatif dengan discount offered yaitu -38%
# - Weigth in grams memiliki korelasi negatif dengan customer care calls yaitu -28%
# - Customer care calls memiliki korelasi positif dengan cost of the product yaitu 38%
# - Customer care calls memiliki sedikit korelasi positif dengan prior purchase yaitu 18%

# %% [markdown]
# <h2> EDA <h2>

# %%
plt.figure(figsize=(16, 24))

# Plot Warehouse_block
plt.subplot(8, 2, 1)
sns.barplot(x=data['Warehouse_block'].value_counts().index, 
            y=data['Warehouse_block'].value_counts(), 
            palette='magma')
plt.title('Warehouse Block')

# Plot Mode_of_Shipment
plt.subplot(8, 2, 2)
sns.barplot(x=data['Mode_of_Shipment'].value_counts().index, 
            y=data['Mode_of_Shipment'].value_counts(),
            palette='magma')
plt.title('Mode of Shipment')

# Plot Costumer Care Calls
plt.subplot(8, 2, 3)
sns.barplot(x=data['Customer_care_calls'].value_counts().index, 
            y=data['Customer_care_calls'].value_counts(),
            palette='magma')
plt.title('Costumer Care Calls')

# Plot Costumer Rating
plt.subplot(8, 2, 4)
sns.barplot(x=data['Customer_rating'].value_counts().index, 
            y=data['Customer_rating'].value_counts(),
            palette='magma')
plt.title('Costumer Rating')
plt.xlabel('Customer Rating')
plt.ylabel('Count')

# Plot Prior Customer
plt.subplot(8, 2, 5)
sns.barplot(x=data['Prior_purchases'].value_counts().index, 
            y=data['Prior_purchases'].value_counts(),
            palette='magma')
plt.title('Prior Purchases')

# Plot Prior Importance
plt.subplot(8, 2, 6)
sns.barplot(x=data['Product_importance'].value_counts().index, 
            y=data['Product_importance'].value_counts(),
            palette='magma')
plt.title('Product Importance')

# Plot Gender
plt.subplot(8, 2, 7)
sns.barplot(x=data['Gender'].value_counts().index, 
            y=data['Gender'].value_counts(),
            palette='magma')
plt.title('Gender')

# Plot Reached On Time
plt.subplot(8, 2, 8)
sns.barplot(x=data['Reached.on.Time_Y.N'].value_counts().index, 
            y=data['Reached.on.Time_Y.N'].value_counts(),
            palette='magma')
plt.title('Reached On Time')


# Atur jarak antar subplot
plt.tight_layout()

# Tampilkan plot
plt.show()
# Out:
# /var/folders/xs/_gsslqss2jnc185r0yh4s5m80000gn/T/ipykernel_86023/600596449.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /var/folders/xs/_gsslqss2jnc185r0yh4s5m80000gn/T/ipykernel_86023/600596449.py:12: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /var/folders/xs/_gsslqss2jnc185r0yh4s5m80000gn/T/ipykernel_86023/600596449.py:19: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /var/folders/xs/_gsslqss2jnc185r0yh4s5m80000gn/T/ipykernel_86023/600596449.py:26: FutureWarning:
#
#
#
# ...

# %% [markdown]
# Dari grafik di atas, kita dapat menyimpulkan sebagai berikut:-
# - Blok gudang F memiliki nilai lebih banyak daripada semua blok gudang lainnya.
# - Pada kolom mode pengiriman, kita dapat melihat dengan jelas bahwa kapal mengirimkan sebagian besar produk ke pelanggan.
# - Sebagian besar pelanggan menelepon 3 sampai 4 kali ke customer care.
# - Peringkat Pelanggan tidak memiliki banyak variasi yang dimana hampir semua sama rata.
# - Sebagian besar pelanggan memiliki 3 pembelian sebelumnya.
# - Dapat kita katakan bahwa sebagian besar produk memiliki kepetingan yang rendah.
# - Kolom Jenis Kelamin tidak memiliki banyak variasi yang dimana gender pembeli disini sama rata.
# - Lebih banyak produk yang tidak sampai tepat waktu daripada produk yang sampai tepat waktu.

# %% [markdown]
# <h3> Data Categorical<h3>

# %%
# Membuat data kategorik agar mudah dilihat
data_categorical = data.select_dtypes(include=['object'])
data_categorical.head()
# Out:
#   Warehouse_block Mode_of_Shipment Product_importance Gender
# 0               D           Flight                low      F
# 1               F           Flight                low      M
# 2               A           Flight                low      M
# 3               B           Flight             medium      M
# 4               C           Flight             medium      F

# %% [markdown]
# Warehouse Block

# %%
warehouse_block = data_categorical['Warehouse_block'].value_counts().reset_index()
warehouse_block.columns = ['Warehouse', 'Value']
fig = px.pie(
    warehouse_block,
    names='Warehouse',
    values='Value',
    color_discrete_sequence=px.colors.sequential.Pinkyl_r
)
fig.update_traces(textinfo='percent')
fig.show()

# %%
# Plot antara Warehouse Block dan Product Importance
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Warehouse_block', hue = 'Product_importance', palette='magma')
plt.show()

# %% [markdown]
# Seperti yang sudah di visualisasikan sebelumnya, gudang F adalah memiliki isi  paling banyal. Rata-rata barang disetiap gudang juga memiliki kepentingan yang rendah

# %%
# Plot antara Warehouse Block dan Reached on Time
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Warehouse_block', hue = 'Reached.on.Time_Y.N', palette='magma')
plt.show()

# %% [markdown]
# Setiap gudang memiliki tingkat tepat waktu yanng cukup baik dalam pengiriman produk

# %% [markdown]
# Mode of Shipment

# %%
mode_shipment = data_categorical['Mode_of_Shipment'].value_counts().reset_index()
mode_shipment.columns = ['Shipment', 'Value']
fig = px.pie(
    mode_shipment,
    names='Shipment',
    values='Value',
    color_discrete_sequence=px.colors.sequential.Greens_r
)
fig.update_traces(textinfo='percent')
fig.show()

# %%
# Plot antara Mode of Shipment dan Reached On Time
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Mode_of_Shipment', hue = 'Reached.on.Time_Y.N', palette='viridis')
plt.show()

# %% [markdown]
# Pengiriman banyak dilakukan dengan menggunakan kapal dan tingkat tepat waktunya jauh lebih baik dibandingkan dengan lewat jalur darat ataupun udara. Karena jika dilihat perbandingan bar antara Y or N pada Flight dan Road tidak jauh berbeda, sedangkan pada Ship cukup jauh

# %%
# Plot antara Mode of Shipment dan Costumer Care Calls
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Mode_of_Shipment', hue = 'Customer_care_calls', palette='viridis')
plt.show()

# %% [markdown]
# Dikarenakan mode pengiriman kapal yang paling banyak, jadi kemungkinan telfon juga lebih tinggi dan rata-rata customer menelfon 3-4kali

# %% [markdown]
# Product Importance

# %%
importance = data_categorical['Product_importance'].value_counts().reset_index()
importance.columns = ['Importance', 'Value']
fig = px.pie(
    importance,
    names='Importance',
    values='Value',
    color_discrete_sequence=px.colors.sequential.Inferno_r
)
fig.update_traces(textinfo='percent')
fig.show()

# %%
# Plot antara Product Importance dan Reached On Time
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Product_importance', hue = 'Reached.on.Time_Y.N', palette='Spectral')
plt.show()

# %% [markdown]
# Rata-rata produk akan sampai tepat waktu tidak dilihat dari seberapa penting barangnya berarti mereka memperlakukan pengiriman sama

# %% [markdown]
# Gender

# %%
gender = data_categorical['Gender'].value_counts().reset_index()
gender.columns = ['Gender', 'Value']
fig = px.pie(
    gender,
    names='Gender',
    values='Value',
    color_discrete_sequence=px.colors.sequential.Blues_r
)
fig.update_traces(textinfo='percent')
fig.show()

# %%
# Plot antara Gender dan Customer Care Calls
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Gender', hue = 'Customer_care_calls', palette='Blues')
plt.show()

# %% [markdown]
# Customer perempuan maupun laki-laki memiliki tingkat calls yang sama

# %%
# Plot antara Gender dengan Reached On Time
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Gender', hue = 'Reached.on.Time_Y.N', palette='Blues')
plt.show()

# %% [markdown]
# Customer perempuan maupun laki-laki juga memiliki tingkat paket sampai yang sama, jadi tidak ada perbedaan dalam pengirimannya

# %% [markdown]
# <h3> Data Numeric<h3>

# %%
# Membuat data kategorik agar mudah dilihat
data_numeric = data.select_dtypes(include=['number'])
data_numeric.head()
# Out:
#    Customer_care_calls  Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    4                2                  177                3
# 1                    4                5                  216                2
# 2                    2                2                  183                4
# 3                    3                3                  176                4
# 4                    2                2                  184                3
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# 3                10           1177                    1
# 4                46           2484                    1

# %% [markdown]
# Customer Care Calls

# %%
calls = data_numeric['Customer_care_calls'].value_counts().reset_index()
calls.columns = ['Calls', 'Value']
fig = px.pie(
    calls,
    names='Calls',
    values='Value',
    color_discrete_sequence=px.colors.sequential.Oranges_r
)
fig.update_traces(textinfo='percent')
fig.show()

# %%
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Customer_care_calls', hue = 'Reached.on.Time_Y.N', palette='Oranges')
plt.show()

# %% [markdown]
# Rata-rata customer banyak menelfon walaupun dominan barangnya akan sampai tepat waktu

# %% [markdown]
# Customer Rating

# %%
rate = data_numeric['Customer_rating'].value_counts().reset_index()
rate.columns = ['Rating', 'Value']
fig = px.pie(
    rate,
    names='Rating',
    values='Value',
    color_discrete_sequence=px.colors.sequential.Reds_r
)
fig.update_traces(textinfo='percent')
fig.show()

# %%
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Customer_rating', hue = 'Reached.on.Time_Y.N', palette='Reds')
plt.show()

# %% [markdown]
# Sama rata

# %% [markdown]
# Cost of the Product

# %%
plt.figure(figsize = (12, 5))
ax = sns.distplot(data['Cost_of_the_Product'], bins = 100, color = 'r')
plt.show()
# Out:
# /var/folders/xs/_gsslqss2jnc185r0yh4s5m80000gn/T/ipykernel_86023/813068486.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Nilai harga produk berkisar dari sekitar 0 hingga 300, menunjukkan variasi harga produk yang cukup luas dalam dataset.

# %%
px.box(data , x = 'Reached.on.Time_Y.N', y = 'Cost_of_the_Product', 
       color = 'Reached.on.Time_Y.N', template = 'ggplot2')

# %% [markdown]
# Pada bagian ini, produk yang terlambat cenderung lebih tinggi harganya dibandingkan yang tidak terlambat.

# %% [markdown]
# Prior Purchases

# %%
prior = data_numeric['Prior_purchases'].value_counts().reset_index()
prior.columns = ['Prior', 'Value']
fig = px.pie(
    prior,
    names='Prior',
    values='Value',
    color_discrete_sequence=px.colors.sequential.Purp_r
)
fig.update_traces(textinfo='percent')
fig.show()

# %%
plt.figure(figsize = (12, 5))
sns.countplot(data, x = 'Prior_purchases', hue = 'Reached.on.Time_Y.N', palette='Purples')
plt.show()

# %% [markdown]
# Hampir semua sampai dengan tepat waktu, terkecuali produk dengan 5 pembelian sebelumnya lebih banyak tidak sampai tepat waktu

# %% [markdown]
# Discount Offered

# %%
plt.figure(figsize = (12, 5))
ax = sns.distplot(data['Discount_offered'], bins = 50, color = 'r')
plt.show()
# Out:
# /var/folders/xs/_gsslqss2jnc185r0yh4s5m80000gn/T/ipykernel_86023/2025649692.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Diskon yang ditawarkan <10% cukup banyak. Puncak yang paling tinggi berada pada diskon di sekitar 0-5%, menunjukkan bahwa mayoritas produk dalam dataset tidak memiliki diskon atau diskon yang ditawarkan sangat kecil. Sehingga dapat kita simpulkan diskon >10% sangat jarang atau sedikit ditawarkan.

# %%
px.box(data , x = 'Reached.on.Time_Y.N', y = 'Discount_offered', 
       color = 'Reached.on.Time_Y.N', template = 'ggplot2')

# %% [markdown]
# Dikarenakan perseberan discount banyak di 0-10, maka kemungkinan barang yang discount memiliki keterlambatan dalam pengiriman.

# %% [markdown]
# Weight in Grams

# %%
plt.figure(figsize = (12, 5))
ax = sns.distplot(data['Weight_in_gms'], bins = 100, color = 'r')
plt.show()
# Out:
# /var/folders/xs/_gsslqss2jnc185r0yh4s5m80000gn/T/ipykernel_86023/1898728569.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Berat produk paling banyak dikisaran 0-2000 dan 4000-6000 jadi kemungkinan customer membeli barangnya itu jika tidak banyak ataupun satu-satu

# %%
px.box(data , x = 'Reached.on.Time_Y.N', y = 'Weight_in_gms', 
       color = 'Reached.on.Time_Y.N', template = 'ggplot2')

# %% [markdown]
# Rata-rata pengiriman yang tepat waktu ada di kisaran 1000-400 dan yang tidak tepat waktu berkisar di 4000-6000. Berarti berat berpengaruh dalam waktu pengiriman.

# %% [markdown]
# <h3> 1. Apakah jumlah panggilan customer berpengaruh bagi cepatnya pengiriman? <h3>

# %%
plt.figure(figsize = (12, 5))
sns.lineplot(data, x = 'Customer_care_calls', y = 'Customer_rating', hue = 'Gender', ci = 5)
plt.title("Hubungan antara Customer Care Calls dan Customer Rating (By Gender)")
plt.show()
# Out:
# /var/folders/xs/_gsslqss2jnc185r0yh4s5m80000gn/T/ipykernel_86023/3241033573.py:2: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 5)` for the same effect.

# %%
plt.figure(figsize = (12, 5))
sns.barplot(data, x = 'Customer_care_calls', y = 'Customer_rating', hue = 'Reached.on.Time_Y.N')
plt.show()

# %% [markdown]
# Ketika jumlah panggilan pelanggan meningkat, pengiriman yang tiba tepat waktu meningkat dibandingkan dengan pengiriman yang tidak tepat waktu. Hal ini menunjukkan bahwa panggilan layanan pelanggan sangat penting untuk mengirimkan pengiriman kepada pelanggan tepat waktu.

# %% [markdown]
# <h3> 2. Apa faktor yang mempengaruhi customer dalam rating produk? <h3>

# %%
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()
data['Mode_of_Shipment'] = encoder.fit_transform(data['Mode_of_Shipment'])
data['Product_importance'] = encoder.fit_transform(data['Product_importance'])
data['Warehouse_block'] = encoder.fit_transform(data['Warehouse_block'])
data['Gender'] = encoder.fit_transform(data['Gender'])
data
# Out:
#        Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0                    3                 0                    4
# 1                    4                 0                    4
# 2                    0                 0                    2
# 3                    1                 0                    3
# 4                    2                 0                    2
# ...                ...               ...                  ...
# 10994                0                 2                    4
# 10995                1                 2                    4
# 10996                2                 2                    5
# 10997                4                 2                    5
# 10998                3                 2                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# 1                    5                  216                2
# ...

# %%
features=['Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
          'Cost_of_the_Product', 'Prior_purchases','Product_importance', 
          'Gender','Reached.on.Time_Y.N']
for f in features:
    related = data['Customer_rating'].corr(data[f])
    print("%s: %f" % (f,related))
# Out:
# Warehouse_block: 0.010169
# Mode_of_Shipment: 0.001679
# Customer_care_calls: 0.012209
# Cost_of_the_Product: 0.009270
# Prior_purchases: 0.013179
# Product_importance: 0.003157
# Gender: 0.002775
# Reached.on.Time_Y.N: 0.013119

# %%
correlations = [data['Customer_rating'].corr(data[f]) for f in features ]
data_features = pd.DataFrame({'Features': features, 'Correlation': correlations}) 
data_features.plot(x ='Features', y='Correlation', kind = 'line',
                    figsize=(20,5), title='Customer Rating Correlation with other features', 
                    marker='.', markersize=15)                

plt.xlabel('Features')
plt.ylabel('Customer Ratings')
# Out:
# Text(0, 0.5, 'Customer Ratings')

# %% [markdown]
# Customer rating memiliki pengaruh dari sampainya paket tepat waktu, pembelian sebelumnya, telfon layanan, biaya produk, dan dari gudang mana. Jadi, hal ini menunjukkan bahwa pelayanan yang baik bagi pelanggan sangat penting untuk mencapai rating yang baik.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
data1 = pd.concat([data, pd.get_dummies(data['Warehouse_block'])], axis=1).drop('Warehouse_block', axis=1)
data1 = pd.concat([data, pd.get_dummies(data['Mode_of_Shipment'])], axis=1).drop('Mode_of_Shipment', axis=1)
data1 = pd.concat([data, pd.get_dummies(data['Product_importance'])], axis=1).drop('Product_importance', axis=1)
data1 = pd.concat([data, pd.get_dummies(data['Gender'], prefix='Sex')], axis=1).drop('Gender', axis=1)
data1
# Out:
#        Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0                    3                 0                    4
# 1                    4                 0                    4
# 2                    0                 0                    2
# 3                    1                 0                    3
# 4                    2                 0                    2
# ...                ...               ...                  ...
# 10994                0                 2                    4
# 10995                1                 2                    4
# 10996                2                 2                    5
# 10997                4                 2                    5
# 10998                3                 2                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# 1                    5                  216                2
# ...

# %%
x = data.drop('Reached.on.Time_Y.N', axis=1)
y = data['Reached.on.Time_Y.N']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
    
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(x_train), index = x_train.index, columns = x_train.columns)
X_test = pd.DataFrame(scaler.transform(x_test), index = x_test.index, columns = x_test.columns)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {test_accuracy}")
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.6418181818181818
#               precision    recall  f1-score   support
#
#            0       0.56      0.57      0.57       895
#            1       0.70      0.69      0.70      1305
#
#     accuracy                           0.64      2200
#    macro avg       0.63      0.63      0.63      2200
# weighted avg       0.64      0.64      0.64      2200
# /Users/gregoriavalen/anaconda3/envs/deep_learningg/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
model_rf = RandomForestClassifier()
model_rf.fit(x_train, y_train)

y_pred_rf = model_rf.predict(x_test)

test_accuracy = accuracy_score(y_test, y_pred_rf)
print(f"Test Accuracy: {test_accuracy}")
print(classification_report(y_test, y_pred_rf))
# Out:
# Test Accuracy: 0.6718181818181819
#               precision    recall  f1-score   support
#
#            0       0.58      0.73      0.64       895
#            1       0.77      0.64      0.70      1305
#
#     accuracy                           0.67      2200
#    macro avg       0.67      0.68      0.67      2200
# weighted avg       0.69      0.67      0.67      2200
